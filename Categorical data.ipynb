# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
dataset=pd.read_csv('Data.csv')
dataset
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
dataset.dropna(inplace=True)
dataset.isnull().sum()
# Out:
# Country      0
# Age          0
# Salary       0
# Purchased    0
# dtype: int64

# %%
#Accessing via index location(iloc)
X = dataset.iloc[:, :-1].values
X
# Out:
# array([['France', 44.0, 72000.0],
#        ['Spain', 27.0, 48000.0],
#        ['Germany', 30.0, 54000.0],
#        ['Spain', 38.0, 61000.0],
#        ['France', 35.0, 58000.0],
#        ['France', 48.0, 79000.0],
#        ['Germany', 50.0, 83000.0],
#        ['France', 37.0, 67000.0]], dtype=object)

# %%
dataset
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 5   France  35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
dataset.isnull().sum()
# Out:
# Country      0
# Age          0
# Salary       0
# Purchased    0
# dtype: int64

# %%
#working on categorical data - LABEL ENCODER
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

X[:,0]=labelencoder.fit_transform(X[:,0])

#The zero above indicates the first column
X=np.array(X, dtype='int32')
#We need to convert into integer


labelencoder
# Out:
# LabelEncoder()

# %%
LabelEncoder
# Out:
# sklearn.preprocessing.label.LabelEncoder

# %%
X
# Out:
# array([[    0,    44, 72000],
#        [    2,    27, 48000],
#        [    1,    30, 54000],
#        [    2,    38, 61000],
#        [    0,    35, 58000],
#        [    0,    48, 79000],
#        [    1,    50, 83000],
#        [    0,    37, 67000]], dtype=int32)

# %%
#working on categorical data - DUMMY VAR

from sklearn.preprocessing import OneHotEncoder
onehotencoder=OneHotEncoder(categorical_features=[0])
X=onehotencoder.fit_transform(X)
dummy
# Out:
# /srv/conda/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:390: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-2dfe28cc6fa7> in <module>
#       3 from sklearn.preprocessing import OneHotEncoder
#       4 onehotencoder=OneHotEncoder(categorical_features=[0])
# ----> 5 X=onehotencoder.fit_transform(X)
#       6 dummy
#
# /srv/conda/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py in fit_transform(self, X, y)
#     512             return _transform_selected(
#     513                 X, self._legacy_fit_transform, self.dtype,
# --> 514                 self._categorical_features, copy=True)
#     515         else:
# ...

# %%
dummy=pd.get_dummies(dataset['Country'])
dummy
# Out:
#    France  Germany  Spain
# 0       1        0      0
# 1       0        0      1
# 2       0        1      0
# 3       0        0      1
# 5       1        0      0
# 7       1        0      0
# 8       0        1      0
# 9       1        0      0

# %%
dataset=pd.concat([dataset,dummy],axis=1)
dataset
# Out:
#    Country   Age   Salary Purchased  France  Germany  Spain  France  Germany  \
# 0   France  44.0  72000.0        No       1        0      0       1        0
# 1    Spain  27.0  48000.0       Yes       0        0      1       0        0
# 2  Germany  30.0  54000.0        No       0        1      0       0        1
# 3    Spain  38.0  61000.0        No       0        0      1       0        0
# 5   France  35.0  58000.0       Yes       1        0      0       1        0
# 7   France  48.0  79000.0       Yes       1        0      0       1        0
# 8  Germany  50.0  83000.0        No       0        1      0       0        1
# 9   France  37.0  67000.0       Yes       1        0      0       1        0
#
#    Spain
# 0      0
# 1      1
# 2      0
# 3      1
# 5      0
# 7      0
# 8      0
# 9      0

# %%
dataset=pd.read_csv('Data.csv')
dataset.Purchased.replace(('Yes', 'No'), (1,0), inplace=True)

dataset
# Out:
#    Country   Age   Salary  Purchased
# 0   France  44.0  72000.0          0
# 1    Spain  27.0  48000.0          1
# 2  Germany  30.0  54000.0          0
# 3    Spain  38.0  61000.0          0
# 4  Germany  40.0      NaN          1
# 5   France  35.0  58000.0          1
# 6    Spain   NaN  52000.0          0
# 7   France  48.0  79000.0          1
# 8  Germany  50.0  83000.0          0
# 9   France  37.0  67000.0          1

# %%
dataset.dropna(inplace=True)
y=dataset.iloc[:,3].values
y
# Out:
# array([0, 1, 0, 0, 1, 1, 0, 1])

# %%
dataset
# Out:
#    Country   Age   Salary  Purchased
# 0   France  44.0  72000.0          0
# 1    Spain  27.0  48000.0          1
# 2  Germany  30.0  54000.0          0
# 3    Spain  38.0  61000.0          0
# 5   France  35.0  58000.0          1
# 7   France  48.0  79000.0          1
# 8  Germany  50.0  83000.0          0
# 9   France  37.0  67000.0          1

# %%
dataset.drop(['Country'], axis=1)
dataset
# Out:
#    Country   Age   Salary  Purchased
# 0   France  44.0  72000.0          0
# 1    Spain  27.0  48000.0          1
# 2  Germany  30.0  54000.0          0
# 3    Spain  38.0  61000.0          0
# 5   France  35.0  58000.0          1
# 7   France  48.0  79000.0          1
# 8  Germany  50.0  83000.0          0
# 9   France  37.0  67000.0          1

# %% [markdown]
# # Step 5: Splitting data set into Training & Testing set

# %%
from sklearn.model_selection import train_test_split

X_train,X_test, y_train=train_test_split(X,y,test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-06d5496424cd> in <module>
#       1 from sklearn.model_selection import train_test_split
#       2
# ----> 3 X_train,X_test, y_train=train_test_split(X,y,test_size=0.2)
#
# ValueError: too many values to unpack (expected 3)
