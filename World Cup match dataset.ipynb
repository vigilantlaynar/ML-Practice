# %% [markdown]
# # Step 1: IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Step 2: IMPORTING DATA SET

# %%
df=pd.read_csv('WorldCupMatches.csv')
df

# %%
#Total no of rows and columns
df.shape
# Out:
# (4572, 20)

# %%
#Starting row to ending row
df.index
# Out:
# RangeIndex(start=0, stop=4572, step=1)

# %%
#Get information about all columns in a list format
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %% [markdown]
# # STEP 3 - CHECK OUT MISSING VALUES

# %%
#This is all the missing data in the dataset we have imported
df.isnull().sum()
# Out:
# Year                    3720
# Datetime                3720
# Stage                   3720
# Stadium                 3720
# City                    3720
# Home Team Name          3720
# Home Team Goals         3720
# Away Team Goals         3720
# Away Team Name          3720
# Win conditions          3720
# Attendance              3722
# Half-time Home Goals    3720
# Half-time Away Goals    3720
# Referee                 3720
# Assistant 1             3720
# Assistant 2             3720
# RoundID                 3720
# MatchID                 3720
# Home Team Initials      3720
# Away Team Initials      3720
# dtype: int64

# %% [markdown]
# # Step 3: METHODS TO SOLVE MISSING VALUES PROBLEM
# #Method 1: Remove the fields which have null data
# #Method 2: Replace the null values by some other values

# %%
#Method 1 is used here
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Year                    0
# Datetime                0
# Stage                   0
# Stadium                 0
# City                    0
# Home Team Name          0
# Home Team Goals         0
# Away Team Goals         0
# Away Team Name          0
# Win conditions          0
# Attendance              0
# Half-time Home Goals    0
# Half-time Away Goals    0
# Referee                 0
# Assistant 1             0
# Assistant 2             0
# RoundID                 0
# MatchID                 0
# Home Team Initials      0
# Away Team Initials      0
# dtype: int64

# %%
df.shape
# Out:
# (850, 20)

# %%
#Method 2 - replace the NaN value with mean, median or mode value

df['Year'].mean()
# Out:
# 1985.0211764705882

# %%
df.shape
# Out:
# (850, 20)

# %%
df['Year'].mean()
# Out:
# 1985.0211764705882

# %%
df['Year'].tail()
# Out:
# 847    2014.0
# 848    2014.0
# 849    2014.0
# 850    2014.0
# 851    2014.0
# Name: Year, dtype: float64

# %%
df['Year'].replace(np, NaN, df['Year'].mean()).tail()

#Cannot be used as NaN has been replaced
#Use new Jupyter notebook to execute
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-737d97e7751b> in <module>
# ----> 1 df['Year'].replace(np, NaN, df['Year'].mean()).tail()
#       2
#       3 #Cannot be used as NaN has been replaced
#       4 #Use new Jupyter notebook to execute
#
# NameError: name 'NaN' is not defined

# %%
df
# Out:
#        Year              Datetime                     Stage  \
# 0    1930.0  13 Jul 1930 - 15:00                    Group 1
# 1    1930.0  13 Jul 1930 - 15:00                    Group 4
# 2    1930.0  14 Jul 1930 - 12:45                    Group 2
# 3    1930.0  14 Jul 1930 - 14:50                    Group 3
# 4    1930.0  15 Jul 1930 - 16:00                    Group 1
# 5    1930.0  16 Jul 1930 - 14:45                    Group 1
# 6    1930.0  17 Jul 1930 - 12:45                    Group 2
# 7    1930.0  17 Jul 1930 - 14:45                    Group 4
# 8    1930.0  18 Jul 1930 - 14:30                    Group 3
# 9    1930.0  19 Jul 1930 - 12:50                    Group 1
# 10   1930.0  19 Jul 1930 - 15:00                    Group 1
# 11   1930.0  20 Jul 1930 - 13:00                    Group 2
# 12   1930.0  20 Jul 1930 - 15:00                    Group 4
# 13   1930.0  21 Jul 1930 - 14:50                    Group 3
# 14   1930.0  22 Jul 1930 - 14:45                    Group 1
# ...

# %% [markdown]
# # Step 4: Categorial Values

# %% [markdown]
# # LabelEncoder()
#
# working on categorical data
#     from sklearn.preprocessing import LabelEncoder
#     label_encoder = LabelEncoder()
#     X[;0]=label_encoder.fit_transform(X[;0])

# %% [markdown]
# # Dummy Variables
#
# from sklearn.preprocessing import OneHotEncoder
# onehotencoder=OneHotEncoder(categorical_features=[0])
# X=onehotencoder.fit_transform(X)
# dummy=pd.get_dummies(dataset['Country'])
# dummy
